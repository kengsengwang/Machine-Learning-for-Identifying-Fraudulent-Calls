# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import (accuracy_score, precision_score, recall_score, 
                           f1_score, roc_auc_score, confusion_matrix, 
                           classification_report, precision_recall_curve, 
                           average_precision_score)
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\DELL\Documents\Machine Learning for Identifying Fraudulent Calls\data\cleaned_calls.csv")

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset from the specified path
file_path = r"C:\Users\DELL\Documents\Machine Learning for Identifying Fraudulent Calls\data\cleaned_calls.csv"
df = pd.read_csv(file_path)

# 1. Dataset Structure Inspection
print("=== Data Inspection ===")
# Check the first few rows of the dataset
print(df.head())

# Check dataset dimensions (rows, columns)
print(f"\nDataset Dimensions: {df.shape}")

# Get data types of each column
print(f"\nData Types:\n{df.dtypes}")

# Check for missing values
print(f"\nMissing Values:\n{df.isnull().sum()}")

# Get the unique values in each column
print(f"\nUnique Values Per Column:\n{df.nunique()}")

# 2. Column Definitions:
#  - ID: Unique identifier for each call (int)
#  - Call Duration: Length of the call in seconds (int)
#  - Call Frequency: Number of calls made by the person (int)
#  - Financial Loss: Monetary loss associated with the call (float)
#  - Flagged by Carrier: Carrier's flag of suspicion ('Suspicious', 'Unlikely', 'Very Suspicious')
#  - Is International: Whether the call is international ('Yes', 'No')
#  - Previous Contact Count: Number of previous interactions (int)
#  - Country Prefix: Country code of the phone number (str)
#  - Call Type: Type of call made ('Voip', 'Mobile', 'Telegram', etc.)
#  - Timestamp: Date and time of the call (datetime)
#  - Device Battery: Device battery status during the call ('Fully Charged', 'Charging', 'Not Charging')
#  - Scam Call: Target variable indicating whether the call was a scam ('Scam', 'Not Scam')
# Out:
# === Data Inspection ===
#        ID  Call Duration  Call Frequency  Financial Loss Flagged by Carrier  \
# 0  947429           -719              12       42.130000         Suspicious
# 1  540498            116               3       29.900000           Unlikely
# 2  434243             29              16      723.460000    Very Suspicious
# 3  903537           -563               4       64.287478           Unlikely
# 4  969179            312              19        0.000000           Unlikely
#
#   Is International  Previous Contact Count Country Prefix Call Type  \
# 0              Yes                       1             95      Voip
# 1              Yes                       0             91    Mobile
# 2              Yes                       2             91      Voip
# 3              Yes                       3             91  Telegram
# 4              Yes                       0             91  Telegram
#
#              Timestamp Device Battery Scam Call
# ...

# %% [markdown]
# This dataset consists of 100 records and 12 columns, each containing specific information related to phone calls. Here’s a breakdown of the data:
# Columns:
#
#     ID: A unique identifier for each record (100 unique values).
#
#     Call Duration: The duration of the call in seconds (80 unique values, with some negative values which might need investigation).
#
#     Call Frequency: The frequency of calls (19 unique values).
#
#     Financial Loss: The amount of financial loss associated with the call (61 unique values).
#
#     Flagged by Carrier: Whether the call was flagged by the carrier (3 unique values: 'Suspicious', 'Unlikely', 'Very Suspicious').
#
#     Is International: Whether the call was international (2 unique values: Yes or No).
#
#     Previous Contact Count: The number of previous contacts (7 unique values).
#
#     Country Prefix: The country code for the call (7 unique values).
#
#     Call Type: The type of the call (6 unique values, including VoIP, Mobile, and Telegram).
#
#     Timestamp: The timestamp of the call (100 unique values, representing different call times).
#
#     Device Battery: The device’s battery status at the time of the call (3 unique values: Fully Charged, Charging, etc.).
#
#     Scam Call: A flag indicating whether the call was a scam (2 unique values: Scam or Not Scam).
#
# Dataset Overview:
#
#     Dimensions: There are 100 rows (records) and 12 columns (features).
#
#     Data Types: The data types include integers (int64), floating-point numbers (float64), and objects (strings) for categorical data.
#
#     Missing Values: There are no missing values in any of the columns.
#
#     Unique Values: Several columns have multiple unique values, such as Call Type, Flagged by Carrier, and Scam Call. This suggests varied categories and classifications for different calls.
#
# Key Observations:
#
#     There are some negative values in the Call Duration column, which might need to be addressed or validated as they don't typically make sense for call durations.
#
#     The Financial Loss column has a range of different values, and there might be some entries where the loss is recorded as zero, which could indicate non-scam calls or other anomalies.
#
#     The Flagged by Carrier column has different categories that could help classify calls based on the carrier's evaluation.
#
#     Scam detection is the key target variable, as indicated by the Scam Call column, which distinguishes between scam and non-scam calls.
#
# Overall, this dataset appears to be designed for a fraud detection task, likely related to identifying scam calls based on various features, including call type, duration, frequency, and carrier flags.

# %%
# 3. Descriptive Statistics
print(f"\nDescriptive Statistics:\n{df.describe()}")
# Out:
# Descriptive Statistics:
#                   ID  Call Duration  Call Frequency  Financial Loss  \
# count     100.000000     100.000000      100.000000      100.000000
# mean   567471.710000      73.560000       10.100000       77.365802
# std    272092.606058     279.908763        5.463377      185.025127
# min    119036.000000    -719.000000        3.000000     -556.660000
# 25%    321274.500000     -42.500000        6.000000        0.000000
# 50%    572815.000000      39.000000        9.000000       12.636549
# 75%    822813.750000     267.250000       15.000000       77.365802
# max    985620.000000     663.000000       23.000000      723.460000
#
#        Previous Contact Count
# count              100.000000
# mean                 2.050000
# std                  1.799972
# min                  0.000000
# 25%                  0.000000
# 50%                  2.000000
# 75%                  3.000000
# max                  6.000000

# %% [markdown]
# The descriptive statistics provide a summary of the key measures of central tendency, dispersion, and range for each numerical column in the dataset. Here's a breakdown:
# 1. Call Duration
#
#     Count: There are 100 records for call durations.
#
#     Mean: The average call duration is 73.56 seconds.
#
#     Standard Deviation: The spread of call durations is quite large (279.91 seconds), indicating a wide range of call lengths.
#
#     Min: The shortest call duration is -719 seconds, which is a negative value and may require investigation or correction.
#
#     25% (Q1): The 25th percentile is -42.5 seconds, showing that a quarter of the calls had durations lower than this (possibly due to erroneous or outlier values).
#
#     50% (Median): The median call duration is 39 seconds, suggesting that half of the calls were shorter than this.
#
#     75% (Q3): The 75th percentile is 267.25 seconds, indicating that three-quarters of the calls had durations lower than this value.
#
#     Max: The longest call lasted 663 seconds.
#
# 2. Call Frequency
#
#     Count: There are 100 records for call frequency.
#
#     Mean: The average number of calls is 10.1.
#
#     Standard Deviation: The variation in call frequency is 5.46, suggesting some calls occurred more frequently than others.
#
#     Min: The minimum value is 3, meaning the least frequent calls happened at least 3 times.
#
#     25% (Q1): 25% of records had 6 or fewer calls.
#
#     50% (Median): The median frequency of calls is 9, meaning half the calls had a frequency lower than 9.
#
#     75% (Q3): 75% of records had 15 or fewer calls.
#
#     Max: The maximum frequency of calls is 23, indicating the highest number of calls recorded for a particular entry.
#
# 3. Financial Loss
#
#     Count: There are 100 records for financial loss.
#
#     Mean: The average financial loss is 77.37 units (likely in monetary terms).
#
#     Standard Deviation: The spread of financial loss is quite wide (185.03), indicating there are some records with very high or low financial losses.
#
#     Min: The minimum value is -556.66, which is negative and suggests a need for validation or correction, as it typically shouldn't be negative.
#
#     25% (Q1): The 25th percentile is 0, meaning that a quarter of the calls had no financial loss or no measurable loss.
#
#     50% (Median): The median financial loss is 12.64, suggesting that half of the records had losses lower than this value.
#
#     75% (Q3): The 75th percentile is 77.37, meaning that three-quarters of the calls had a loss lower than this.
#
#     Max: The maximum financial loss is 723.46, indicating that some calls resulted in very high financial losses.
#
# 4. Previous Contact Count
#
#     Count: There are 100 records for previous contact count.
#
#     Mean: The average number of previous contacts is 2.05, indicating most calls involved a relatively low number of prior contacts.
#
#     Standard Deviation: The standard deviation is 1.80, showing variability in the number of previous contacts.
#
#     Min: The minimum value is 0, meaning there are records with no prior contacts.
#
#     25% (Q1): 25% of the calls had no prior contacts (value of 0).
#
#     50% (Median): The median is 2, indicating that half of the calls had 2 or fewer previous contacts.
#
#     75% (Q3): The 75th percentile is 3, meaning three-quarters of the calls had 3 or fewer previous contacts.
#
#     Max: The maximum number of previous contacts is 6, indicating some calls were preceded by multiple interactions.
#
# Key Insights:
#
#     Call Duration has a large range and includes negative values, which may require attention for data cleaning.
#
#     Call Frequency is moderately spread out, with a peak frequency of 23 calls for a single record.
#
#     Financial Loss shows high variability, with some records having significant losses (up to 723.46), while others report no loss at all.
#
#     Previous Contact Count is fairly low on average, but there is still a wide variation in how many prior contacts each call had.
#
# These descriptive statistics help identify patterns, outliers, and potential data quality issues (e.g., negative values for Call Duration and Financial Loss).

# %%
# 4. Visualize Missing Data (using heatmap if possible, else a different method)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# 5. Inspect Target Variable Distribution (Scam Call)
print(f"\nTarget Variable Distribution (Scam Call):\n{df['Scam Call'].value_counts()}")

# Visualize the distribution of the 'Scam Call' target variable
plt.figure(figsize=(8, 6))
sns.countplot(x='Scam Call', data=df, palette='Blues')
plt.title('Distribution of Scam Calls')
plt.xlabel('Scam Call')
plt.ylabel('Count')
plt.show()
# Out:
# Target Variable Distribution (Scam Call):
# Scam Call
# Not Scam    56
# Scam        44
# Name: count, dtype: int64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20620\2165586413.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Scam Call', data=df, palette='Blues')

# %%
# 6. Check Numerical Features: Call Duration, Call Frequency, Financial Loss
numeric_features = ['Call Duration', 'Call Frequency', 'Financial Loss', 'Previous Contact Count']
print(f"\nNumerical Features Summary:\n{df[numeric_features].describe()}")

# Plot histograms for numerical features
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numeric_features, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[feature], kde=True, bins=30)
    plt.title(f'Distribution of {feature}')
plt.tight_layout()
plt.show()
# Out:
# Numerical Features Summary:
#        Call Duration  Call Frequency  Financial Loss  Previous Contact Count
# count     100.000000      100.000000      100.000000              100.000000
# mean       73.560000       10.100000       77.365802                2.050000
# std       279.908763        5.463377      185.025127                1.799972
# min      -719.000000        3.000000     -556.660000                0.000000
# 25%       -42.500000        6.000000        0.000000                0.000000
# 50%        39.000000        9.000000       12.636549                2.000000
# 75%       267.250000       15.000000       77.365802                3.000000
# max       663.000000       23.000000      723.460000                6.000000

# %% [markdown]
# The Numerical Features Summary provides a snapshot of the key statistical measures for the four numerical columns in the dataset. Here's a breakdown of each feature:
# 1. Call Duration
#
#     Count: 100 records of call duration.
#
#     Mean: The average call duration is 73.56 seconds.
#
#     Standard Deviation (std): The variation is high, with a standard deviation of 279.91 seconds, indicating significant variability in call durations.
#
#     Minimum (min): The shortest recorded call duration is -719 seconds, which is negative and likely represents an error or anomaly in the data.
#
#     25% (Q1): -42.5 seconds, suggesting that 25% of the calls had durations less than or equal to this (again, negative values need validation).
#
#     Median (50%): The median call duration is 39 seconds, meaning that half of the calls lasted longer than this, and half were shorter.
#
#     75% (Q3): The 75th percentile is 267.25 seconds, meaning three-quarters of calls had durations shorter than this.
#
#     Maximum (max): The longest recorded call was 663 seconds.
#
# 2. Call Frequency
#
#     Count: 100 records for call frequency.
#
#     Mean: The average call frequency is 10.1, indicating that, on average, each record had 10 calls.
#
#     Standard Deviation (std): The variation in call frequency is 5.46, suggesting that some records have much higher frequencies than others.
#
#     Minimum (min): The lowest frequency is 3 calls, which is the least number of calls recorded in a record.
#
#     25% (Q1): 6 calls, meaning 25% of records had 6 or fewer calls.
#
#     Median (50%): 9 calls, indicating that half of the records had fewer than 9 calls.
#
#     75% (Q3): 15 calls, meaning three-quarters of records had 15 or fewer calls.
#
#     Maximum (max): The highest frequency recorded is 23 calls.
#
# 3. Financial Loss
#
#     Count: 100 records for financial loss.
#
#     Mean: The average financial loss is 77.37 units (likely in monetary terms).
#
#     Standard Deviation (std): The variation in financial loss is quite large, with a standard deviation of 185.03, indicating a high range of financial losses across records.
#
#     Minimum (min): The lowest financial loss is -556.66, which is negative and might suggest an error or needs further validation.
#
#     25% (Q1): 0 units, meaning 25% of records had no financial loss.
#
#     Median (50%): 12.64 units, suggesting that half of the records had a financial loss less than or equal to this value.
#
#     75% (Q3): 77.37 units, meaning three-quarters of records had a financial loss of this amount or less.
#
#     Maximum (max): The highest financial loss recorded is 723.46 units, which suggests some calls incurred very high financial losses.
#
# 4. Previous Contact Count
#
#     Count: 100 records for previous contact count.
#
#     Mean: The average number of previous contacts is 2.05.
#
#     Standard Deviation (std): The standard deviation is 1.80, indicating moderate variability in the number of previous contacts.
#
#     Minimum (min): The minimum value is 0, meaning there are records with no prior contacts.
#
#     25% (Q1): 0 contacts, meaning a quarter of the calls had no previous contacts.
#
#     Median (50%): 2 contacts, indicating that half of the records had 2 or fewer prior contacts.
#
#     75% (Q3): 3 contacts, meaning three-quarters of records had 3 or fewer prior contacts.
#
#     Maximum (max): The maximum number of previous contacts is 6, indicating that some records had a substantial number of prior contacts.
#
# Summary of Key Insights:
#
#     Call Duration shows a high degree of variability, including negative values which suggest potential data issues.
#
#     Call Frequency is relatively consistent, with an average of about 10 calls per record, but it still varies from 3 to 23.
#
#     Financial Loss also varies significantly, with some calls showing very large losses, while others report none or negative values.
#
#     Previous Contact Count has a low average and is distributed across a narrow range, with most calls having a few prior contacts.
#
# Overall, there is significant variability in call durations, financial losses, and call frequency, and some of the values in Call Duration and Financial Loss may need further cleaning or validation.

# %%
# 7. Categorical Feature Analysis (e.g., 'Flagged by Carrier', 'Call Type')
categorical_features = ['Flagged by Carrier', 'Is International', 'Call Type', 'Device Battery']
plt.figure(figsize=(15, 10))
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=feature, hue='Scam Call', data=df, palette='Set1')
    plt.title(f'{feature} by Scam Call')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 8. Temporal Analysis (extract hour, day of the week, etc. from Timestamp)
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['Hour'] = df['Timestamp'].dt.hour
df['DayOfWeek'] = df['Timestamp'].dt.dayofweek
df['Month'] = df['Timestamp'].dt.month

# Visualize the hour-based scam distribution
plt.figure(figsize=(10, 5))
sns.countplot(x='Hour', hue='Scam Call', data=df, palette='coolwarm')
plt.title('Scam Calls by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Count')
plt.show()

# Visualize the day of the week-based scam distribution
plt.figure(figsize=(10, 5))
sns.countplot(x='DayOfWeek', hue='Scam Call', data=df, palette='coolwarm')
plt.title('Scam Calls by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Count')
plt.show()

# Visualize the month-based scam distribution
plt.figure(figsize=(10, 5))
sns.countplot(x='Month', hue='Scam Call', data=df, palette='coolwarm')
plt.title('Scam Calls by Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()

# %%
# 9. Correlation Analysis (for numerical features)
corr_matrix = df[numeric_features].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix for Numerical Features')
plt.show()

# %%
# 10. Feature Engineering: Create some new features
df['Duration_abs'] = df['Call Duration'].abs()  # Absolute value of Call Duration
df['Has_Financial_Loss'] = (df['Financial Loss'] > 0).astype(int)
df['High_Frequency'] = (df['Call Frequency'] > df['Call Frequency'].median()).astype(int)

# 11. Final Data Review (final check of transformations)
print(f"\nUpdated Data Preview:\n{df.head()}")
# Out:
# Updated Data Preview:
#        ID  Call Duration  Call Frequency  Financial Loss Flagged by Carrier  \
# 0  947429           -719              12       42.130000         Suspicious
# 1  540498            116               3       29.900000           Unlikely
# 2  434243             29              16      723.460000    Very Suspicious
# 3  903537           -563               4       64.287478           Unlikely
# 4  969179            312              19        0.000000           Unlikely
#
#   Is International  Previous Contact Count Country Prefix Call Type  \
# 0              Yes                       1             95      Voip
# 1              Yes                       0             91    Mobile
# 2              Yes                       2             91      Voip
# 3              Yes                       3             91  Telegram
# 4              Yes                       0             91  Telegram
#
#             Timestamp Device Battery Scam Call  Hour  DayOfWeek  Month  \
# ...

# %% [markdown]
# The updated data preview provides additional columns and features compared to the earlier dataset, enriching the information available for analysis. Here’s a breakdown of the new columns and their meanings:
# 1. Existing Columns:
#
#     ID: A unique identifier for each record (remains unchanged).
#
#     Call Duration: The duration of the call in seconds, including negative values (which may require further investigation).
#
#     Call Frequency: The number of calls made from a particular phone number.
#
#     Financial Loss: The financial loss associated with the call.
#
#     Flagged by Carrier: Indicates the carrier's evaluation of the call, with categories like "Suspicious," "Unlikely," and "Very Suspicious."
#
#     Is International: A binary feature indicating whether the call was international.
#
#     Previous Contact Count: The number of prior contacts made from the same phone number.
#
#     Country Prefix: The country code for the call.
#
#     Call Type: Type of call, such as "Voip," "Mobile," or "Telegram."
#
#     Timestamp: The date and time the call was made.
#
# 2. New Columns:
#
#     Device Battery: Indicates the device's battery status at the time of the call, such as "Fully Charged" or "Charging."
#
#     Scam Call: A flag indicating whether the call was identified as a scam ("Scam" or "Not Scam").
#
# 3. Time-Related Features:
#
#     Hour: The hour when the call was made (ranging from 0 to 23, indicating the time of day).
#
#     DayOfWeek: The day of the week the call was made, represented as an integer (1 for Monday, 2 for Tuesday, etc.).
#
#     Month: The month when the call occurred (ranging from 1 for January to 12 for December).
#
# 4. Derived Features:
#
#     Duration_abs: The absolute value of the call duration. This removes negative durations, which likely result from data issues, by converting them to positive numbers.
#
#     Has_Financial_Loss: A binary feature indicating whether the call has a financial loss (1 if there was a financial loss, 0 if none).
#
#     High_Frequency: A binary feature indicating whether the call frequency is considered high (1 for high frequency, 0 for lower frequency). This could be based on some threshold defined by the dataset.
#
# Key Insights:
#
#     The Device Battery column adds a new layer of information about the device’s power status during the call.
#
#     The Scam Call feature identifies whether the call was a scam, which is critical for the classification task.
#
#     The Hour, DayOfWeek, and Month columns allow for deeper analysis of patterns based on when calls occurred, such as peak scam activity times or frequent scam calls at certain hours.
#
#     Duration_abs corrects any negative call duration issues by converting them to positive values.
#
#     The derived features, Has_Financial_Loss and High_Frequency, help in flagging calls with significant financial impact and high call frequency, which are likely to be correlated with fraudulent or suspicious activity.
#
# Summary:
#
# The updated dataset now contains both the original features and additional time-based features that enhance the ability to analyze patterns in call data. It also includes derived columns that make it easier to assess the financial and frequency aspects of calls, potentially aiding in the detection of fraud or scams.

# %% [markdown]
# Enhanced Scam Call Detection with Improved Feature Engineering and Model Evaluation

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import shap
df = pd.read_csv(r"C:\Users\DELL\Documents\Machine Learning for Identifying Fraudulent Calls\data\cleaned_calls.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[44], line 8
#       6 import seaborn as sns
#       7 from datetime import datetime
# ----> 8 import shap
#       9 df = pd.read_csv(r"C:\Users\DELL\Documents\Machine Learning for Identifying Fraudulent Calls\data\cleaned_calls.csv")
#
# ModuleNotFoundError: No module named 'shap'

# %%
# !pip install shap

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as snsy
from datetime import datetime
import shap
df = pd.read_csv(r"C:\Users\DELL\Documents\Machine Learning for Identifying Fraudulent Calls\data\cleaned_calls.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 8
#       6 import seaborn as sns
#       7 from datetime import datetime
# ----> 8 import shap
#       9 df = pd.read_csv(r"C:\Users\DELL\Documents\Machine Learning for Identifying Fraudulent Calls\data\cleaned_calls.csv")
#
# ModuleNotFoundError: No module named 'shap'

# %%
# !pip install shap
